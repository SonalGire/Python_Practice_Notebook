# %% [markdown]
# <a href="https://colab.research.google.com/github/SonalGire/Python_Practice_Notebook/blob/main/if_else_programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2>📘 Python If-Else Practice – Key Highlights</h2>
#
# <br>
#
# *   Contains 60 Python practice questions focused on if, elif, and else concepts
# *  Designed to improve logical thinking and decision-making skills
#
# * Covers basic to intermediate conditional problems
# * Includes comparison operators and logical conditions
# * Solves real-world decision-based scenarios
# * Uses simple syntax and multiple logical approaches for better understanding
# * Helpful for beginners to practice condition-based programming step by step

# %% [markdown]
# <h3>Fundamental Level 25 Questions :</h3>

# %% [markdown]
# 1. Positive, Negative, or Zero: Get a number from the user and print if it's positive, negative, or zero.

# %%
# Positive, Negative, or Zero: Get a number from the user and print if it's positive, negative, or zero.
while True:
  n = int(input("Enter a number :"))
  if n>0:
    print(f"Entered {n} number is Positive.")
  elif n==0:
    print(f"Entered {n} number is Zero.")
  else:
    print(f"Entered {n} number is Negative.")
    break
# Out:
# Enter a number :1
# Entered 1 number is Positive.
# Enter a number :2
# Entered 2 number is Positive.
# Enter a number :3
# Entered 3 number is Positive.
# Enter a number :0
# Entered 0 number is Zero.
# Enter a number :-2
# Entered -2 number is Negative.

# %% [markdown]
# 2. Even or Odd: Get an integer from the user and print if it's even or odd.

# %%
# Even or Odd: Get an integer from the user and print if it's even or odd.

while True:
  n = int(input("Enter a number :"))
  if n %2==0:
    print(f"Entered {n} number is Even.")
    break
  else:
    print(f"Entered {n} number is Odd.")
    break
# Out:
# Enter a number :2
# Entered 2 number is Even.

# %% [markdown]
# 3. Eligible to Vote: Ask for a user's age. If they are 18 or older, print "You are eligible to vote." Otherwise, print "You are not eligible to vote yet."

# %%
""" Eligible to Vote: Ask for a user's age. If they are 18 or older, print "You are eligible to vote."
Otherwise, print "You are not eligible to vote yet."""
while True:
  age = int(input("Enter Your Age : "))
  if age>=18:
    print("You are eligible to vote.")
  else :
    print("You are not eligible to vote yet.")
    break
# Out:
# Enter Your Age : 19
# You are eligible to vote.
# Enter Your Age : 12
# You are not eligible to vote yet.

# %% [markdown]
# 4. Largest of Two Numbers: Get two numbers from the user and print the larger one.

# %%
# Largest of Two Numbers: Get two numbers from the user and print the larger one.
while True:
  a = int(input("Enter first number : "))
  b = int(input("Enter second number : "))
  if a>b:
    print(f"{a} is greater (largest) number than {b}")
  elif a==b:
    print(f"Both number are equal.")
  else :
    print(f"{b} is greater (largest) number than {a}")
# Out:
# Enter first number : 1
# Enter second number : 2
# 2 is greater (largest) number than 1

# %% [markdown]
# 5. Smallest of Two Numbers: Get two numbers from the user and print the smaller one.

# %%
# Smallest of Two Numbers: Get two numbers from the user and print the smaller one.

while True:
  a = int(input("Enter first number : "))
  b = int(input("Enter second number : "))
  if a<b:
    print(f"{a} is smaller (smallest) than {b}")
  elif a==b:
    print(f"Both number are equal.")
  else :
    print(f"{b} is smaller (smallest) than {a}")
    break
# Out:
# Enter first number : 3
# Enter second number : 1
# 1 is smaller (smallest) than 3

# %% [markdown]
# 6. Login Check: Ask for a username and a password. If username is "admin" and password is "password123", print "Login Successful". Otherwise, print "Invalid Credentials".

# %%
# Login Check: Ask for a username and a password. If username is "admin" and password is "password123", print "Login Successful". Otherwise, print "Invalid Credentials".

uid = "admin"
pwd = "password123"

username = input("Enter a username: ")
password = input("Enter your paasword :")

if uid==username and pwd == password :
  print("Login Successful.")
else:
  print("Invalid Credentials")
# Out:
# Enter a username: admin
# Enter your paasword :password123
# Login Successful.

# %% [markdown]
# 7. Leap Year Check: Ask for a year. Print if it's a leap year (divisible by 4, but not by 100 unless also divisible by 400).

# %%
# Leap Year Check: Ask for a year. Print if it's a leap year (divisible by 4, but not by 100 unless also divisible by 400).

year = int(input("Enter a year to check Leap Year : "))

if (year%4==0 and year%100 != 0) or year%400 == 0:
  print(f"Yes,{year} is a Leap year.")
else:
  print(f"No,{year} is not a Leap year.")
# Out:
# Enter a year to check Leap Year : 1984
# Yes,1984 is a Leap year.

# %% [markdown]
# 8. Vowel or Consonant: Get a single character from the user. Print if it's a vowel (a, e, i, o, u) or a consonant.

# %%
# Vowel or Consonant: Get a single character from the user. Print if it's a vowel (a, e, i, o, u) or a consonant.
list1 = ['a','e','i','o','u']
ch = input("Enter any single character : ")
s =ch.lower()

if s in list1:
  print(f"{ch} is Vowel.")
else:
  print(f"{ch} is Consonant.")
# Out:
# Enter any single character : Q
# Q is Consonant.

# %% [markdown]
# 9. Grade Calculator (Pass/Fail): Get a student's score. If score is 50 or above, print "Pass". Otherwise, print "Fail".

# %%
# Grade Calculator (Pass/Fail): Get a student's score. If score is 50 or above, print "Pass". Otherwise, print "Fail".

name = input("Enter student name: ")
score = int(input("Enter your score : "))

if score>50:
  print(f"Yes,{name} is Pass and scored {score}%.")
else:
  print(f"No,{name} is Failed.")
# Out:
# Enter student name: sd
# Enter your score : 67
# Yes,sd is Pass and scored 67%.

# %% [markdown]
# 10. Temperature Converter (Simple): Ask for a temperature in Celsius. If it's above 30, print "It's hot!". Otherwise, print "It's moderate.".

# %%
# Temperature Converter (Simple): Ask for a temperature in Celsius. If it's above 30, print "It's hot!". Otherwise, print "It's moderate.".

temp = int(input("Enter current Temperature in Celsius(*C): "))

if temp>30:
  print(f"It's hot!")
else:
  print(f"It's moderate.")
# Out:
# Enter current Temperature in Celsius(*C): 23
# It's moderate.

# %% [markdown]
# 11. Number Range Check: Get a number. If it's between 10 and 20 (inclusive), print "Within range". Otherwise, print "Out of range".

# %%
# Number Range Check: Get a number. If it's between 10 and 20 (inclusive), print "Within range". Otherwise, print "Out of range".

n = int(input("Enter a number for range check: "))

if n in range(10,20+1):
  print(f"Within range.")
else:
  print(f"Out of range.")
# Out:
# Enter a number for range check: 20
# Within range.

# %% [markdown]
# 12. Divisible by 5: Get a number. Print if it's divisible by 5.

# %%
#  Divisible by 5: Get a number. Print if it's divisible by 5.

n = int(input("Enter a number it is divisible by 5 or not : "))

if n%5==0:
  print(f"Yes,{n} is divisible by 5.")
else:
  print(f"No,{n} is not divisible by 5.")
# Out:
# Enter a number it is divisible by 5 or not : 25
# Yes,25 is divisible by 5.

# %% [markdown]
# 13. Equality Check: Get two numbers. Print if they are equal or not equal.

# %%
# Equality Check: Get two numbers. Print if they are equal or not equal.
a = int(input("Enter first number : "))
b= int(input("Enter second number : "))

if a==b:
  print(f"{a} and {b} are equal numbers")
else:
  print(f"Both number are not equal.")
# Out:
# Enter first number : 2
# Enter second number : 3
# Both number are not equal.

# %% [markdown]
# 14. Discount Eligibility: Ask for a purchase amount. If it's over $100, print "You get a 10% discount!".

# %%
# Discount Eligibility: Ask for a purchase amount. If it's over $100, print "You get a 10% discount!".
bill = int(input("Enter your total bill amount : "))

if bill>100:
  print("You get a 10% discount!")
else:
  print("For getting 10% discount,you have to puchase over $100.")
# Out:
# Enter your total bill amount : 120
# You get a 10% discount!

# %% [markdown]
# 15. Ticket Price: Ask for age. If age is less than 5, ticket is free. Else, ticket is $10. Print the ticket price.

# %%
# Ticket Price: Ask for age. If age is less than 5, ticket is free. Else, ticket is $10. Print the ticket price.
while True:
  age = int(input("Enter Your Age : "))
  if age<5:
    print("Ticket is free.")
  else :
    print("Ticket is $10. Pay now!!")
    break
# Out:
# Enter Your Age : 3
# Ticket is free.
# Enter Your Age : 23
# Ticket is $10. Pay now!!

# %% [markdown]
# 16. Simple Calculator (Addition): Get two numbers and an operator. If the operator is '+', print their sum. (Just addition for now).

# %%
# Simple Calculator (Addition): Get two numbers and an operator. If the operator is '+', print their sum. (Just addition for now).
a = int(input("Enter first number : "))
b= int(input("Enter second number : "))
ope = input("Enter operator :")

if ope == '+':
  c = a+b
  print(f"{a} + {b} =  ",c)
elif ope == '-':
  c=a-b
  print(f"{a} - {b} =  ",c)
elif ope == '*':
  c=a*b
  print(f"{a} * {b} =  ",c)
elif ope == '/':
  c=a/b
  print(f"{a} / {b} =  ",c)
elif ope == '//':
  c=a//b
  print(f"{a} // {b} =  ",c)
else:
  print("Invalid details,.")
# Out:
# Enter first number : 5
# Enter second number : 15
# Enter operator :+
# 5 + 15 =   20

# %% [markdown]
# 17. Traffic Light: Ask for the color of a traffic light (red, yellow, green). Print the action (Stop, Slow down, Go).

# %%
# Traffic Light: Ask for the color of a traffic light (red, yellow, green). Print the action (Stop, Slow down, Go).
light = input("What is the color of traffic light ?  ")
color = light.lower()

if color =='red':
  print("Stop!")
elif color =='yellow':
  print("Slow down !")
elif light =='green':
  print("Go!")
else:
  print("Give valid color.")
# Out:
# What is the color of traffic light ?  YelloW
# Slow down !

# %% [markdown]
# 18. Weekend or Weekday: Ask for a day of the week. Print if it's a "Weekend" (Saturday/Sunday) or "Weekday".

# %%
#  Weekend or Weekday: Ask for a day of the week. Print if it's a "Weekend" (Saturday/Sunday) or "Weekday".
dl=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
day_list=list(map(str.lower, dl))

y = input("Which is a day? ")
day = y.lower()


if day=='Saturday' or day=='Sunday':
  print("Weekend")
elif day in day_list:
  print("Weekday")
else:
  print("Invalid day added.")
# Out:
# Which is a day? friday
# Weekday

# %% [markdown]
# 19. Positive and Even: Get a number. Print "Positive and Even" if both conditions are true.

# %%
# Positive and Even: Get a number. Print "Positive and Even" if both conditions are true.
y = int(input("Enter a number "))

if y>0 and y%2==0:
  print("Positive and Even")
elif y>0 and y%2 !=0:
  print("Positive and Odd")
elif y<0 and y%2 ==0:
  print("Negative and Even")
else:
  print("Negative and Odd")
# Out:
# Enter a number 2
# Positive and Even

# %% [markdown]
# 20. Negative or Odd: Get a number. Print "Negative or Odd" if at least one condition is true.

# %%
# Negative or Odd: Get a number. Print "Negative or Odd" if at least one condition is true.
n = int(input("Enter a negative number only :"))

if y<0 or y%2 !=0:
  print("Negative and Odd")
else:
  print("Invalid number added.")
# Out:
# Enter a negative number only :-2
# Negative and Odd

# %% [markdown]
# 21. Triangle Type (Sides): Get three side lengths. If all are equal, print "Equilateral". Otherwise, print "Not Equilateral". (Focus on just one type for now)

# %%
# Triangle Type (Sides): Get three side lengths. If all are equal, print "Equilateral". Otherwise, print "Not Equilateral". (Focus on just one type for now).
l1 = int(input("Enter a length of side 1: "))
l2 = int(input("Enter a length of side 2: "))
l3= int(input("Enter a length of side 3: "))

if (l1 == l2) and (l3 == l1) and (l2 == l3):
  print("Equilateral Triangle.")
else:
  print("Not Equilateral Triangle.")
# Out:
# Enter a length of side 1: 2
# Enter a length of side 2: 2
# Enter a length of side 3: 2
# Equilateral Triangle.

# %% [markdown]
# 22. Character Case: Get a single character. Print if it's an uppercase letter, a lowercase letter, or neither.

# %%
#  Character Case: Get a single character. Print if it's an uppercase letter, a lowercase letter, or neither.
y =input("Enter a single character : ")

if len(y) != 1:
  print("Pls, enter a single character only")
elif y.isupper() == True:
  print(f"Capital letter : {y}")
elif y.islower() == True:
  print(f"Small letter : {y}")
else:
  print("Neither capital or small.")
# Out:
# Enter a single character : A
# Capital letter : A

# %% [markdown]
# 23. Check for "Python": Ask the user to type "Python". If they type it correctly, print "Correct!". Otherwise, print "Try again.".

# %%
# Check for "Python": Ask the user to type "Python". If they type it correctly, print "Correct!". Otherwise, print "Try again.".
a = 'Python'

while True:
  b= input("Type here python:")
  if b==a :
    print("Correct !")
    break
  else:
    print("Try again!")
    break
# Out:
# Type here python:Python
# Correct !

# %% [markdown]
# 24. Password Length: Ask for a password. If its length is 8 or more characters, print "Strong password". Otherwise, print "Weak password".

# %%
# Password Length: Ask for a password. If its length is 8 or more characters, print "Strong password". Otherwise, print "Weak password".
y =input("Enter a password : ")

if len(y) >= 8:
  print("Strong password.")
else:
  print("Weak password.")
# Out:
# Enter a password : 1239876543
# Strong password.

# %% [markdown]
# 25. Multiples of 3 and 5: Get a number. Print if it's a multiple of both 3 and 5.

# %%
# Multiples of 3 and 5: Get a number. Print if it's a multiple of both 3 and 5.

y =int(input("Enter a number : "))

if y%3 ==0 and y%5==0:
  print(f"{y} number is multiple of 3 and 5.")
else:
  print(f"{y} number is not multiple of 3 and 5.")
# Out:
# Enter a number : 15
# 15 number is multiple of 3 and 5.

# %% [markdown]
# - <h1>Intermediate Level 25 Questions ( Nested & Chained Conditionals):</h1>

# %% [markdown]
# 1. Largest of Three Numbers: Get three numbers and print the largest one.

# %%
# Largest of Three Numbers: Get three numbers and print the largest one.

a = int(input("Enter first number : "))
b = int(input("Enter second number : "))
c = int(input("Enter third number : "))

if a>b and a>c:
  print(f"{a} = First is the greatest number")
if b>a and b>c:
  print(f"{b} = Second is the greatest number")
elif c>a and c>b:
  print(f"{c} = Third is the greatest number")
# Out:
# Enter first number : 5
# Enter second number : 6
# Enter third number : 3
# 6 = Second is the greatest number

# %% [markdown]
# 2. Smallest of Three Numbers: Get three numbers and print the smallest one.

# %%
# Smallest of Three Numbers: Get three numbers and print the smallest one.
a = int(input("Enter first number : "))
b = int(input("Enter second number : "))
c = int(input("Enter third number : "))

if a<b and a<c:
  print(f"{a} = First is the smallest number")
if b<a and b<c:
  print(f"{b} = Second is the smallest number")
elif c<a and c<b:
  print(f"{c} = Third is the smallest number")
# Out:
# Enter first number : 2
# Enter second number : 4
# Enter third number : 3
# 2 = First is the smallest number

# %% [markdown]
# 3. Grade Calculator (A, B, C, D, F): Get a student's score (0-100). Assign grades: A (90-100), B (80-89), C (70-79), D (60-69), F (below 60).

# %%
# Grade Calculator (A, B, C, D, F): Get a student's score (0-100). Assign grades: A (90-100), B (80-89), C (70-79), D (60-69), F (below 60).

name = input("Enter student name: ")
score = int(input("Enter your score : "))

if score in range(90,100+1):
  print(f"Grade : A ")
elif score in range(80,89+1):
  print(f"Grade : B ")
if score in range(70,79+1):
  print(f"Grade : C ")
if score in range(60,69+1):
  print(f"Grade : D ")
elif score<60:
  print(f"Grade : F ")
# Out:
# Enter student name: sdk
# Enter your score : 95
# Grade : A

# %% [markdown]
# 4. Triangle Type (Sides - Full): Get three side lengths. Print if it's "Equilateral", "Isosceles", or "Scalene".

# %%
# Triangle Type (Sides - Full): Get three side lengths. Print if it's "Equilateral", "Isosceles", or "Scalene".
l1 = int(input("Enter a length of side 1: "))
l2 = int(input("Enter a length of side 2: "))
l3= int(input("Enter a length of side 3: "))

if (l1 == l2) and (l3 == l1):
  print("Equilateral Triangle.")
elif (l1 == l2 and l2 != l3) and (l2 == l3 and l3 != l1):
  print("Isosceles Triangle.")
else:
  print("Scalene Triangle.")
# Out:
# Enter a length of side 1: 3
# Enter a length of side 2: 4
# Enter a length of side 3: 5
# Scalene Triangle.

# %% [markdown]
# 5. Positive, Negative, Even/Odd: Get a number. Print if it's "Positive and Even", "Positive and Odd", "Negative and Even", "Negative and Odd", or "Zero".

# %%
# Positive, Negative, Even/Odd: Get a number. Print if it's "Positive and Even", "Positive and Odd", "Negative and Even", "Negative and Odd", or "Zero".

y = int(input("Enter a number "))

if y>0 and y%2==0:
  print("Positive and Even")
elif y>0 and y%2 !=0:
  print("Positive and Odd")
elif y<0 and y%2 ==0:
  print("Negative and Even")
elif y==0:
  print("Zero")
else:
  print("Negative and Odd")
# Out:
# Enter a number -3
# Negative and Odd

# %% [markdown]
# 7. Ticket Price with Age Groups: Ask for age. 0-5: Free. 6-12: $5. 13-64: $15. 65+: $10. Print the ticket price.

# %%
# Ticket Price with Age Groups: Ask for age. 0-5: Free. 6-12: $5. 13-64: $15. 65+: $10. Print the ticket price.


age = int(input("Enter Your Age : "))

if age<5:
  print("Ticket is free.")
elif age in range(6,12+1):
  print("Ticket is for $5.")
elif age in range(13,64+1):
  print("Ticket is for $15.")
elif age>=65:
  print("Ticket is for $10.")
else :
  print("Invalid details!!")
# Out:
# Enter Your Age : 45
# Ticket is for $15.

# %% [markdown]
# 8. BMI Calculator: Get weight (kg) and height (m). Calculate BMI = weight / (height * height). Print BMI category: Underweight (<18.5), Normal (18.5-24.9), Overweight (25-29.9), Obese (30+).

# %%
# BMI Calculator: Get weight (kg) and height (m). Calculate BMI = weight / (height * height). Print BMI category: Underweight (<18.5), Normal (18.5-24.9), Overweight (25-29.9), Obese (30+).

weight = float(input("Enter Your weight (kg) : "))
height = float(input("Enter Your height (m) : "))

BMI = weight / (height * height)

if BMI < 18.5:
  print("Underweight")
elif BMI >= 18.5 and BMI<= 24.9:
  print("BMI Category: Normal")
elif BMI >=25 and BMI<=29.9:
  print("BMI Category: Overweight")
elif BMI>30:
  print("BMI Category: Obese")
else:
  print("Invalid Details.")
# Out:
# Enter Your weight (kg) : 48
# Enter Your height (m) : 1.52
# BMI Category: Normal

# %% [markdown]
# 9. Quadratic Equation Roots: Get coefficients a, b, c. Calculate discriminant (Δ=b
# 2
#  −4ac). Print if roots are "Real and Distinct", "Real and Equal", or "Complex".

# %%
# Quadratic Equation Roots: Get coefficients a, b, c. Calculate discriminant (Δ=b 2−4ac). Print if roots are "Real and Distinct", "Real and Equal", or "Complex".


a = float(input("Enter coefficient value for a : "))
b = float(input("Enter coefficient value for b : "))
c = float(input("Enter coefficient value for c : "))

discriminant = b**2 - 4*a*c

if discriminant>0:
  print("Real and Distinct")
elif discriminant==0:
  print("Real and Equal")
elif discriminant<0:
  print("Complex")
# Out:
# Enter coefficient value for a : 1.2
# Enter coefficient value for b : 2.4
# Enter coefficient value for c : 1
# Real and Distinct

# %% [markdown]
# 10. Simple ATM Machine: Ask for a PIN. If correct, ask for desired transaction (Withdraw, Deposit, Check Balance). Simulate these actions with basic if-else.

# %%
# Simple ATM Machine: Ask for a PIN. If correct, ask for desired transaction (Withdraw, Deposit, Check Balance). Simulate these actions with basic if-else.

uid = "admin"
pwd = "123"


username = input("Enter a username: ")
password = input("Enter your paasword :")

if uid==username and pwd == password :
  print("Login Successful.")
  balance = 10000
  ts=input(print("\n\nWhich type of Transaction do you need ? Withdraw or Deposit or Check Balance\n\n"))
  if ts == "Withdraw" or ts =='withdraw':
    amt = float(input("Enter amount for withdrwal : "))
    total_balance = balance-amt
    print(f"Take your withdrwal money :{amt} ")
    print(f"Total balance : {total_balance}")
  elif ts == "Deposite" or "deposite":
    amt = float(input("Enter amount for deposite : "))
    total_balance = balance+amt
    print(f"Your deposited money :{amt} ")
    print(f"Total balance : {total_balance}")

  elif ts == "Check Balance" or "check balance":
    print(f"Total balance : {balance}")
else:
  print("Invalid Credentials")
# Out:
# Login Successful.
#
#
# Which type of Transaction do you need ? Withdraw or Deposit or Check Balance

# %% [markdown]
# 11. Number in Range with Specific Property: Get a number. If it's between 1 and 100, and it's even, print "Valid and Even". Otherwise, print "Invalid or Odd".

# %%
# Number in Range with Specific Property: Get a number. If it's between 1 and 100, and it's even, print "Valid and Even". Otherwise, print "Invalid or Odd".

n = int(input("Enter a number : "))
if n>0 and n<=100:
  if n%2==0:
    print("Valid and Even")
  else:
    print("Invalid and Odd")
else:
  print("Invalid Number")
# Out:
# Enter a number : 23
# Invalid and Odd

# %% [markdown]
# 12. Eligibility for Loan: Ask for credit score (0-850) and income. If credit score is 700+ AND income is 50000+, print "Eligible for loan". Else, "Not eligible".

# %%
# Eligibility for Loan: Ask for credit score (0-850) and income. If credit score is 700+ AND income is 50000+, print "Eligible for loan". Else, "Not eligible".

cs = int(input("Enter a credit score :"))


if (cs>=0 and cs<=850):
  inc = int(input("Enter your income amount :"))
  if cs>700 and inc>50000:
    print("Eligible for loan")
  else:
    print("Not eligible for Loan")
else:
    print("Not eligible")
# Out:
# Enter a credit score :478
# Enter your income amount :50008
# Not eligible for Loan

# %% [markdown]
# 13. Month Name from Number: Get a number (1-12). Print the corresponding month name (e.g., 1 -> January). Handle invalid input.

# %%
# Month Name from Number: Get a number (1-12). Print the corresponding month name (e.g., 1 -> January). Handle invalid input.
n = int(input("Enter a number(1-12) then check which is the month according to number :"))

if n==1:
  print("1 -> January")
elif n==2:
  print("2 -> February")
elif n==3:
  print("3 -> March")
elif n==4:
  print("4 -> April")
elif n==5:
  print("5 -> May")
elif n==6:
  print("6 -> June")
elif n==7:
  print("7 -> July")
elif n==8:
  print("8 -> August")
elif n==9:
  print("9 -> September")
elif n==10:
  print("10 -> October")
elif n==11:
  print("11 -> November")
elif n==12:
  print("12 -> December")
else:
  print("Invlid Number")
# Out:
# Enter a number(1-12) then check which is the month according to number :6
# 6 -> June

# %% [markdown]
# 14. Day of Week from Number: Get a number (1-7). Print the corresponding day name (e.g., 1 -> Monday). Handle invalid input.

# %%
# Day of Week from Number: Get a number (1-7). Print the corresponding day name (e.g., 1 -> Monday). Handle invalid input.
n = int(input("Enter a number(1-7) then check which is the day of the week :"))

if n==1:
  print("1 -> Monday")
elif n==2:
  print("2 -> Tuesday")
elif n==3:
  print("3 -> Wedday")
elif n==4:
  print("4 -> Thursday")
elif n==5:
  print("5 -> Friday")
elif n==6:
  print("6 -> Saturday")
elif n==7:
  print("7 -> Sunday")
else:
  print("Invlid Number")
# Out:
# Enter a number(1-7) then check which is the day of the week :7
# 7 -> Sunday

# %% [markdown]
# 15.Traffic Fine Calculator: Ask for speed limit and current speed. If current speed is over speed limit, calculate fine: $100 for every 10 mph over the limit. Add $50 if over 20 mph. Print fine amount.

# %%
# Traffic Fine Calculator: Ask for speed limit and current speed. If current speed is over speed limit, calculate fine: $100 for every 10 mph over the limit. Add $50 if over 20 mph. Print fine amount.
# speed 60 - 100 70 - 50
current_speed = float(input("Enter current speed: "))
speed_limit = 60
fine = 0
if current_speed > speed_limit:
    over_speed = current_speed - speed_limit
    fine = (over_speed // 10) * 100
    if over_speed > 20:
        fine += 50
    print(f"Your fine amount is: ${fine}")
else:
    print("No fine. You're within the speed limit.")
# Out:
# Enter current speed: 180
# Your fine amount is: $1250.0

# %% [markdown]
# 16. Character Type Identifier: Get a character. Print if it's a "Digit", "Uppercase Letter", "Lowercase Letter", or "Special Character".

# %%
# Character Type Identifier: Get a character. Print if it's a "Digit", "Uppercase Letter", "Lowercase Letter", or "Special Character".

ch = input("Enter anything : ")
if ch.isupper():
  print("Uppercase Letter")
elif ch.islower():
  print("Lowercase Letter")
elif ch.isdigit():
  print("Digit")
else:
  print("Special Character")
# Out:
# Enter anything : 124@
# Special Character

# %% [markdown]
# 17.
# Triangle Validity: Get three side lengths. Print if they can form a valid triangle (sum of any two sides must be greater than the third).

# %%
# Triangle Validity: Get three side lengths. Print if they can form a valid triangle (sum of any two sides must be greater than the third).
s1 = int(input("Enter side 1 length :"))
s2 = int(input("Enter side 2 length :"))
s3 = int(input("Enter side 3 length :"))

if (s1+s2)>s3 and (s2+s3)>s1 and (s3+s1)>s2:
  print("Valid Traingle")
else:
  print("Invalid Traingle")
# Out:
# Enter side 1 length :2
# Enter side 2 length :3
# Enter side 3 length :4
# Valid Traingle

# %% [markdown]
# 18. Word Length Category: Get a word. Print if it's "Short" (<=5 chars), "Medium" (6-10 chars), or "Long" (>10 chars).

# %%
# Word Length Category: Get a word. Print if it's "Short" (<=5 chars), "Medium" (6-10 chars), or "Long" (>10 chars).
s = input("Enter any word :")
length = len(s)
if length <=5:
  print("Word length is Short")
elif length>10:
  print("Word length is Long")
elif length>=6 and length<=10:
  print("Word length is Medium")
else:
  print("Invalid Charachter")
# Out:
# Enter any word :shubham
# Word length is Medium

# %% [markdown]
# 19. Year Season: Ask for a month number (1-12). Print the season (e.g., 12, 1, 2 -> Winter; 3, 4, 5 -> Spring, etc.).

# %%
# Year Season: Ask for a month number (1-12). Print the season (e.g., 12, 1, 2 -> Winter; 3, 4, 5 -> Spring, etc.).

winter= [1,2]
spring =[3,4]
summer =[5,6]
monsoon =[7,8,9]
autumn =[10,11]
pre_winter =[12]
n= int(input("Enter a month (1-12):"))

if n in winter:
  print("Season : Winter ")
elif n in spring:
  print("Season : Spring ")
elif n in summer:
  print("Season : Summer ")
elif n in monsoon:
  print("Season : Monsoon ")
elif n in autumn:
  print("Season : Autumn(Sharad)")
elif n in pre_winter:
  print("Season :Pre Winter(Hemant) ")
else:
  print("Invalid number")
# Out:
# Enter a month (1-12):7
# Season : Monsoon

# %% [markdown]
# 20. Simple Rock-Paper-Scissors: Get two player choices (rock, paper, scissors). Determine the winner or a tie.

# %%
# Simple Rock-Paper-Scissors: Get two player choices (rock, paper, scissors). Determine the winner or a tie.

p1 = input("Enter your choice(rock,paper,scissor) : ").lower()
p2 = input("Enter your choice(rock,paper,scissor) : ").lower()

if p1 == p2:
  print("Game is Tie")
elif (p1 == 'paper' and p2== 'rock') or (p1 == 'rock' and p2 == 'scissor') or (p1 == 'scissor' and p2=='paper'):
  print("Player 1 is winner")
elif (p1 == 'paper' and p2== 'scissor') or (p1 == 'rock' and p2 == 'paper') or (p1 == 'scissor' and p2=='rock'):
  print("Player 2 is winner")
else :
  print("Invalid choice")
# Out:
# Enter your choice(rock,paper,scissor) : rock
# Enter your choice(rock,paper,scissor) : paper
# Player 2 is winner

# %% [markdown]
# 21. Discount with Multiple Conditions: Ask for purchase amount and customer type (regular, premium). Premium customers get 15% off if over $50, regular get 10% if over $100. Otherwise, no discount.

# %%
 # Discount with Multiple Conditions: Ask for purchase amount and customer type (regular, premium).
#  Premium customers get 15% off if over $50, regular get 10% if over $100. Otherwise, no discount.

ct = input("Enter customer type(Regular , Premium ) :").lower()
pa = int(input("Enter your Purchase amount :"))

if ct == 'premium' and pa >50:
  dis = pa * 0.15
  total = pa-dis
  print(f"Total Bill : {total}")
elif ct == 'regular' and pa>100:
  dis = pa * 0.1
  total = pa -dis
  print(f"Total Bill : {total}")
else:
  print(f"Total Bill : {pa}")
  print("No discount")
# Out:
# Enter customer type(Regular , Premium ) :regular
# Enter your Purchase amount :70
# Total Bill : 70
# No discount

# %% [markdown]
# 22. Password Strength Checker: Ask for a password. Check if it's at least 8 characters AND contains at least one uppercase letter AND at least one digit. Print "Strong" or "Weak".

# %%
# Password Strength Checker: Ask for a password. Check if it's at least 8 characters AND contains at least one uppercase letter AND at least one digit. Print "Strong" or "Weak".

y =input("Enter a password : ")
l = len(y)

has_uppercase = False
has_digit = False
if l>=8:
  if y.isupper():
    has_uppercase = True
  if y.isdigit():
    has_digit = True

if has_uppercase == True and has_digit == True:
  print("Strong password")
else:
  print("Weak password")
# Out:
# Enter a password : Sonalgire123
# Weak password

# %%
password = input("Enter your password: ")

has_uppercase = False
has_digit = False

for char in password:
  if char.isupper():
    has_uppercase = True
  if char.isdigit():
    has_digit = True

if len(password) >= 8 and has_uppercase and has_digit:
  print("Strong")
else:
  print("Weak")
# Out:
# Enter your password: Xyzsfkeyw12
# Strong

# %% [markdown]
# 23. Guessing Game (Limited Tries): Pick a secret number. Allow the user 3 guesses. Give hints ("Too high", "Too low") and tell them if they won or lost.

# %%
from random import randint
# Guessing Game (Limited Tries): Pick a secret number. Allow the user 3 guesses. Give hints ("Too high", "Too low") and tell them if they won or lost.\

n = randint(1,100)

t = 0
while True:
  secret_num =int(input("Choose any number(1-100):"))
  if secret_num == n:
    print("You are win")
    print(f"The actual number was : {n}")
    break
  elif secret_num >n:
    print("You choose Too high number")
    t +=1
    if t >=7:
      print("You lost")
      print(f"The actual number was : {n}")
      break

  elif secret_num <n:
    print("You choose Too low number")
    t +=1
    if t >=7:
      print("You lost")
      print(f"The actual number was : {n}")
      break
  else :
    print("Invalid number")
    t +=1
    if t >=7:
      print("You lost")
      print(f"The actual number was : {n}")
      break
# Out:
# Choose any number(1-100):78
# You choose Too high number
# Choose any number(1-100):56
# You choose Too low number
# Choose any number(1-100):75
# You choose Too high number
# Choose any number(1-100):60
# You choose Too low number
# Choose any number(1-100):65
# You choose Too low number
# Choose any number(1-100):68
# You choose Too low number
# Choose any number(1-100):72
# You choose Too low number
# You lost
# The actual number was : 74

# %% [markdown]
# 4
#
# 24. Number Property Checker: Get a number. Print if it's positive, even, AND a multiple of 7.

# %%
# Number Property Checker: Get a number. Print if it's positive, even, AND a multiple of 7.

y = int(input("Enter a number "))

if y>0 and y%2==0 and y%7==0:
  print("Positive, even and multiple of 7")
elif y==0:
  print("Zero")
else:
  print("Invalid number")
# Out:
# Enter a number 28
# Positive, even and multiple of 7

# %% [markdown]
# 25. Eligible for Scholarship: Ask for GPA (0-4.0) and extracurricular activities (yes/no). If GPA >= 3.5 AND extracurriculars are 'yes', print "Eligible for scholarship".

# %%
# Eligible for Scholarship: Ask for GPA (0-4.0) and extracurricular activities (yes/no). If GPA >= 3.5
# AND extracurriculars are 'yes', print "Eligible for scholarship".

y = float(input("Enter your CGPA(0-5): "))
a = input("You are doing any extracurricular activities :").lower()

if y>0 and y >=3.5 and a=='yes':
  print("You are eligible for scholarship")
else:
  print("You are not eligible for scholarship")
# Out:
# Enter your CGPA(0-5): 4.8
# You are doing any extracurricular activities :Yes
# You are eligible for scholarship

# %% [markdown]
# 26. Currency Converter (Limited): Ask for an amount in USD and target currency (EUR, GBP). Convert to the target currency using fixed exchange rates (e.g., 1 USD = 0.85 EUR, 0.75 GBP). Handle invalid currency.

# %%
# Currency Converter (Limited): Ask for an amount in USD and target currency (EUR, GBP).
# Convert to the target currency using fixed exchange rates (e.g., 1 USD = 0.85 EUR, 0.75 GBP). Handle invalid currency.

y = float(input("Enter your USD Currency: "))
if y>0:
  eur = y * 0.85
  gbp = y * 0.75
  print("Target currency :")
  print(f"EUR Currency:€{eur}")
  print(f"GBP Currency:£{gbp}")
else:
  print("Invalid Number")
# Out:
# Enter your USD Currency: 5
# Target currency :
# EUR Currency:€4.25
# GBP Currency:£3.75

# %% [markdown]
# <h1> Advance if-else challenges :</h1>

# %% [markdown]
# 1. Comprehensive Leap Year Validator: Get a year from the user. Print if it's a leap year with a clear explanation of why (i.e., "divisible by 4 and not by 100, or divisible by 400"). You should also handle invalid year inputs

# %%
# Comprehensive Leap Year Validator: Get a year from the user. Print if it's a leap year with a clear explanation of why
#  (i.e., "divisible by 4 and not by 100, or divisible by 400"). You should also handle invalid year inputs


year = int(input("Enter a year to check it's leap year :"))

if (year%4==0 and year%100 != 0) or year%400 ==0:
  print(f"Yes, {year} is a leap year because it is divisible by 4 and not by 100, or divisible by 400.")
elif year<0 or year != year.isdigit() :
  print(f"Enter valid year number")
else:
  print(f"No, {year} is not a leap year because it is not divisible by 4 and divisible by 100, or not divisible by 400.")
# Out:
# Enter a year to check it's leap year :2400
# Yes, 2400 is a leap year because it is divisible by 4 and not by 100, or divisible by 400.

# %% [markdown]
# 2. Date Validator: Get the day, month, and year as integers from the user. Determine if the date is valid. This means checking:
#
# - If the month is between 1 and 12.
# - If the day is within the correct range for that month (e.g., April 31st is invalid).
# - If February 29th is only valid in a leap year.
# - Print "Valid Date" or "Invalid Date" along with a specific reason.

# %%
# Date Validator: Get the day, month, and year as integers from the user. Determine if the date is valid. This means checking:

# If the month is between 1 and 12.
# If the day is within the correct range for that month (e.g., April 31st is invalid).\
# If February 29th is only valid in a leap year.
# Print "Valid Date" or "Invalid Date" along with a specific reason.


print("Date Validator:\n\n")
day= int(input("Enter a day number (Date):" ))

if day>0 and day<=31:
  month = input("Enter a month (Month):" ).lower()
  if month == 'february':
    if day==29:
      year = int(input("Enter a year number (year):" ))
      if (year%4==0 and year%100 != 0) or year%400 ==0:
        print(f"February 29th is present in this {year} year and it is a valid date.")
    elif day<=28:
      print("Yes, it is a valid date.")
  elif month in ['april','june','october','november'] and (day>0 and day<=30 ):
    print(f"Yes,it is a valid date for this {month.capitalize()}")
  elif month in ['january','march','may','july','august','september','december'] and (day>0 and day<=31 ):
    print(f"Yes,it is a valid date for this {month.capitalize()}")
else:
  print("Please enter valid date.")
# Out:
# Date Validator:
#
#
# Enter a day number (Date):29
# Enter a month (Month):february
# Enter a year number (year):2024
# February 29th is present in this 2024 year and it is a valid date.

# %% [markdown]
# 3. Advanced Grade Calculator with Weighting: Get scores for three components: Assignments, Midterm, and Final Exam (all out of 100).
#
# - Apply weights: Assignments (20%), Midterm (30%), Final Exam (50%).
# - Calculate the overall percentage.
# - Assign a letter grade (A: 90-100, B: 80-89, C: 70-79, D: 60-69, F: <60).
# - Also, determine a "Pass" or "Fail" status (Pass if total score is 60 or above).
# - Handle invalid individual scores (e.g., scores less than 0 or greater than 100).

# %%
print("Grade Calculator with Weighting:\n\n")

ass = float(input("Enter your assignment score : "))
mt = float(input("Enter your Midterm score : "))
fs =float(input("Enter your final score : "))

ass_score = ass*0.2
mt_score =  mt*0.3
fs_score =fs*0.5


score =(ass_score + mt_score + fs_score)
print(f"Percentage :{score}")

if score>0 and score<=100:
  if score>=60:
    print("Pass")
    if score >=90:
      print(f"Grade : A ")
    elif score >=80:
      print(f"Grade : B ")
    elif score>=70:
      print(f"Grade : C ")
    elif score >=60:
      print(f"Grade : D ")
  else:
    print("Fail")
    print(f"Grade : F ")
else:
  print("Enter valid details")
# Out:
# Grade Calculator with Weighting:
#
#
# Enter your assignment score : 53
# Enter your Midterm score : 42
# Enter your final score : 48
# Percentage :47.2
# Fail
# Grade : F

# %% [markdown]
# 4. Loan Approval System: Design a system based on multiple criteria for loan approval:
#
#
#
# *   Credit Score: (e.g., Excellent: 750+, Good: 700-749, Fair: 650-699, Poor: <650).
# - Annual Income: (e.g., <30k, 30k-60k, >60k).
# - Employment Status: (Employed, Unemployed, Self-Employed).
# - Existing Debts: (High, Moderate, Low).
# - Implement a tiered approval process:
# - Automatically Approved for the best combination (e.g., "Excellent" credit, ">60k" income, "Employed", "Low" debts).
# - Automatically Rejected for the worst combinations (e.g., "Poor" credit or "Unemployed").
# - For other combinations, use nested if-else to determine Conditional Approval (might require higher interest) or Rejected.

# %%
print("Loan Approval System:\n\n")

cs = float(input("Enter credit score :"))
ai = float(input("Enter Annual income :"))
es = input("Enter your Employment Status (Employed, Unemployed, Self-Employed) :").lower()
ed = input("Existing Debts(High, Moderate, Low) : ").lower()

if es not in ['employed', 'unemployed', 'self-employed'] or ed not in ['high', 'moderate', 'low']:
        print("Invalid input for Employment Status or Existing Debts.")
elif cs>=750 and es == "employed" and ai >60000 and ed == 'low':
  print("Loan approved.")
elif cs >=650 and cs<750 and es == 'employed':
  print("Loan will be approve but might require higher interest.")
elif cs<650 or es == 'unemployed':
  print("Loan Rejected.")
else:
  print("Enter correct and valid details otherwise your loan will be reject.")
# Out:
# Loan Approval System:
#
#
# Enter credit score :783
# Enter Annual income :67863
# Enter your Employment Status (Employed, Unemployed, Self-Employed) :Employed
# Existing Debts: (High, Moderate, Low)Low
# Loan approved.

# %% [markdown]
# 5. Multi-Choice Quiz (Single Question with Robust Input):
#
# - Display a question with 4 options (A, B, C, D).
# - Get the user's answer.
# - Provide feedback: "Correct!", "Incorrect. The correct answer was...", or "Invalid option. Please choose A, B, C, or D."
# - Make the check case-insensitive (accept 'a' or 'A'). Ensure it handles extra spaces or unexpected inputs gracefully.

# %%
a='Oxygen'
b='Nitrogen'
c='Carbon_Dioxide'
d='Hydrogen'

opt = {'a' :a,'b':b,'c':c,'d':d}
corr_ans = 'c'

print("Question : Which gas do plants absorb from the atmosphere?")
print(" A) Oxygen\n B) Nitrogen\n C) Carbon_Dioxide\n D) Hydrogen\n")
ans = input("Select a correct option : ").strip().lower()

if ans in opt:
  if ans == corr_ans:
    print("Correct !")
  else:
    print(f"Incorrect. The correct answer was {corr_ans}")

else:
  print("Invalid option. Please choose A, B, C, or D")
# Out:
# Question : Which gas do plants absorb from the atmosphere?
#  A) Oxygen
#  B) Nitrogen
#  C) Carbon_Dioxide
#  D) Hydrogen
#
# Select a correct option : C
# Correct !

# %% [markdown]
#  6. Ticket Booking System with Capacity & Type:
#
# - Set an initial_available_tickets (e.g., 50) and a base price for an 'Adult' ticket (e.g., $15).
# - Ask the user how many tickets they want to buy and the  ticket_type (e.g., 'Adult', 'Child', 'Senior').
# - Set different prices: Child = $8, Senior = $10.
# - Check if enough tickets are available.
# - If yes, calculate the total cost, confirm booking, and update the available tickets.
# - If not, inform the user "Not enough tickets available. Only X left."
# - Handle invalid ticket_type or non-positive number of tickets.

# %%
#  6. Ticket Booking System with Capacity & Type:

# - Set an initial_available_tickets (e.g., 50) and a base price for an 'Adult' ticket (e.g., $15).
# - Ask the user how many tickets they want to buy and the  ticket_type (e.g., 'Adult', 'Child', 'Senior').
# - Set different prices: Child = $8, Senior = $10.
# - Check if enough tickets are available.
# - If yes, calculate the total cost, confirm booking, and update the available tickets.
# - If not, inform the user "Not enough tickets available. Only X left."
# - Handle invalid ticket_type or non-positive number of tickets.

print(" Ticket Booking System :\n\n")
print("Ticket Price :\n A) Adult = $15\n B) Child = $8\n C) Senior = $10\n")
total_seats = 10
user_seats = int(input('How many seats you want to buy :'))

if user_seats <= total_seats:
  a_tkt = int(input('How many seats you want to buy for Adult category:'))
  s_tkt = int(input('How many seats you want to buy for Senior category:'))
  c_tkt = int(input('How many seats you want to buy for Child category:'))
  total_tickets = a_tkt + s_tkt + c_tkt
  total_seats = total_seats - user_seats
  if total_tickets == user_seats:
    if a_tkt >=0 or s_tkt >=0 or c_tkt >=0:
      a_amount = a_tkt * 15
      s_amount = s_tkt * 10
      c_amount = c_tkt * 8
      total_amount = a_amount + s_amount + c_amount
      print(f"Total bill : {total_amount}")
    print(f"Total available seats : {total_seats}")
elif total_seats < user_seats:
  print("Seats are not available")
# Out:
#  Ticket Booking System :
#
#
# Ticket Price :
#  A) Adult = $15
#  B) Child = $8
#  C) Senior = $10
#
# How many seats you want to buy :3
# How many seats you want to buy for Adult category:2
# How many seats you want to buy for Senior category:0
# How many seats you want to buy for Child category:1
# Total bill : 38
# Total available seats : 7

# %% [markdown]
# 7. Age-Based Discounts for Events:
#
# - Get the user's age and the event_type (e.g., "Movie", "Concert",
# "Museum").
# - Apply different discount rules based on both age and event type.
# - Movie: Kids (0-12) 50% off, Seniors (65+) 25% off, others full price.
# - Concert: No discounts.
# - Museum: Free for kids (0-5), 20% off for students (age 13-25, you can ask if they are a student), full price otherwise.
# - Print the final calculated ticket price.
# - Handle invalid age (e.g., negative) or unknown event_type.

# %%
print("Age-Based Discounts for Events:\n")
movie_tkt = 100
museum_tkt = 150
concert_tkt = 300
events = ['movie', 'concert', 'museum']
total = 0

age = int(input("Enter your age :"))
event = input("Enter event_type ('Movie', 'Concert', 'Museum'):").strip().lower()


if age<=0 or age> 120:
  print("Please give valid age")
elif event not in events:
  print("Unknown event type ,Give valid event name.")
elif event == 'movie':
  if age<=12:
    total = movie_tkt * 0.5
  elif age>=65:
    total = movie_tkt * 0.75
  else:
    total = movie_tkt
elif event == 'museum':
  if age <=5:
    total = 0
  elif age in range(13,26):
    is_student = input("Are you a student? (yes/no): ").strip().lower()
    if is_student == 'yes':
      total = museum_tkt * 0.8
    else:
      total = museum_tkt
  else:
    total = museum_tkt
elif event == 'concert':
  total = concert_tkt

print(f"Total amount :{total}")
# Out:
# Age-Based Discounts for Events:
#
# Enter your age :13
# Enter event_type ('Movie', 'Concert', 'Museum'):museum
# Are you a student? (yes/no): yes
# Total amount :120.0

# %% [markdown]
# 8. Interactive ATM Simulation: Implement a basic ATM with initial balance. Allow multiple "Withdraw", "Deposit", "Check Balance", and "Exit" transactions. Include a login with a limited number of PIN attempts.

# %%
uid = "admin"
pwd = "123"

count = 0
while count < 3:
    username = input("Enter a username: ")
    password = input("Enter your password: ")

    if uid == username and pwd == password:
        print("✅ Login Successful.")

        balance = 10000  # Keep this outside so it doesn't reset every time

        while True:
            ts = input("\nWhich type of Transaction do you need? "
                       "(Withdraw, Deposit, Check Balance, Exit):\n").strip().lower()

            if ts == 'withdraw':
                amt = float(input("Enter amount for withdrawal: "))
                if amt > balance:
                    print("⚠ Insufficient balance")
                else:
                    balance -= amt
                    print(f"💰 Take your withdrawal money: {amt}")
                    print(f"💳 Total balance: {balance}")

            elif ts == "deposit":
                amt = float(input("Enter amount for deposit: "))
                balance += amt
                print(f"✅ Your deposited money: {amt}")
                print(f"💳 Total balance: {balance}")

            elif ts == "check balance":
                print(f"💳 Total balance: {balance}")

            elif ts == "exit":
                print("👋 Thank you for using our ATM. Goodbye!")
                break

            else:
                print("❌ Invalid transaction type. Please try again.")

        break  # Exit after user chooses "exit"

    else:
        count += 1
        print("❌ Invalid username or password, Try again.\n")

if count == 3:
    print("🚫 Too many failed login attempts. Account locked.")
# Out:
# Enter a username: admin
# Enter your password: 123
# ✅ Login Successful.
#
# Which type of Transaction do you need? (Withdraw, Deposit, Check Balance, Exit):
# deposit
# Enter amount for deposit: 50000
# ✅ Your deposited money: 50000.0
# 💳 Total balance: 60000.0
#
# Which type of Transaction do you need? (Withdraw, Deposit, Check Balance, Exit):
# withdraw
# Enter amount for withdrawal: 5000
# 💰 Take your withdrawal money: 5000.0
# 💳 Total balance: 55000.0
#
# Which type of Transaction do you need? (Withdraw, Deposit, Check Balance, Exit):
# withdraw
# Enter amount for withdrawal: 20000
# 💰 Take your withdrawal money: 20000.0
# 💳 Total balance: 35000.0
#
# Which type of Transaction do you need? (Withdraw, Deposit, Check Balance, Exit):
# exit
# 👋 Thank you for using our ATM. Goodbye!

# %%
# Interactive ATM Simulation: Implement a basic ATM with initial balance. Allow multiple "Withdraw", "Deposit", "Check Balance", and "Exit" transactions. Include a login with a limited number of PIN attempts.
uid = "admin"
pwd = "123"

count = 0
while count <3:
  username = input("Enter a username: ")
  password = input("Enter your paasword :")

  if uid==username and pwd == password :
    print("Login Successful.")
    balance = 10000
    while True:
      ts=input("\n\nWhich type of Transaction do you need ?( Withdraw, Deposit, Check Balance,exit ):\n").strip().lower()
      if ts =='withdraw':
        amt = float(input("Enter amount for withdrwal : "))
        if amt > balance:
          print("Insufficient balance")
          continue
        else:
          balance = balance-amt
          print(f"Take your withdrwal money :{amt} ")
          print(f"Total balance : {balance}")
      elif ts =="deposit":
        amt = float(input("Enter amount for deposit : "))
        balance = balance+amt
        print(f"Your deposited money :{amt} ")
        print(f"Total balance : {balance}")
      elif ts =="check balance":
        print(f"Total balance : {balance}")
      elif ts == "exit":
        print("👋 Thank you for using our ATM. Goodbye!")
        break
    break
  else:
    count+=1
    print("Invalid username or password,Try again .\n")

if count == 3:
    print("🚫 Too many failed login attempts. Account locked.")
# Out:
# Enter a username: sdrew6yt
# Enter your paasword :124
# Invalid username or password,Try again .
#
# Enter a username: sruyoup
# Enter your paasword :dsre5r
# Invalid username or password,Try again .
#
# Enter a username: etyih
# Enter your paasword :vcg
# Invalid username or password,Try again .
#
# 🚫 Too many failed login attempts. Account locked.

# %% [markdown]
# 9. Variable Shipping Cost: Get item weight and destination (Local, National, International). Calculate base shipping cost by weight tier and destination. Add a surcharge if "express shipping" is requested.

# %%
# Variable Shipping Cost: Get item weight and destination (Local, National, International). Calculate base shipping cost by weight tier and destination. Add a surcharge if "express shipping" is requested.

des = ['local', 'national','international']
print("Variable Shipping Cost:\n")

weight = float(input("Item weight: "))
destination = input("Destination (Local, National, International): ").strip().lower()
express_shipping = input("Express shipping? (yes/no): ").strip().lower()


if weight<0:
  print("Enter valid weight")
elif destination not in des:
  print("Enter valid destination")
elif weight <=1 :
  if destination == 'local':
    cost = 50
  elif destination == 'national':
    cost = 100
  elif destination == 'international':
    cost = 300

elif weight<=5:
  if destination == 'local':
    cost = 80
  elif destination == 'national':
    cost = 200
  elif destination == 'international':
    cost = 500

elif weight>5:
  if destination == 'local':
    cost = 150
  elif destination == 'national':
    cost = 400
  elif destination == 'international':
    cost = 1000

cost= weight*cost
if express_shipping == 'yes' and weight>0:
  cost += 0.8*cost
else:
  cost = cost


print(f"\n\nTotal cost : {cost}")
# Out:
# Variable Shipping Cost:
#
# Item weight: 15
# Destination (Local, National, International): National
# Express shipping? (yes/no): yes
#
#
# Total cost : 10800.0

# %% [markdown]
# 10. Advanced Password Strength: Get a password. Classify it as "Weak", "Moderate", or "Strong" based on length, presence of uppercase, lowercase, digits, and special characters.

# %%
# Advanced Password Strength: Get a password. Classify it as "Weak", "Moderate", or "Strong" based on length, presence of uppercase, lowercase, digits, and special characters.

print("Password strength checker:\n\n")
y =input("Enter a password : ")
l = len(y)

has_uppercase = False
has_digit = False
has_special_char = False
if l>=8:
  if y.isupper():
    has_uppercase = True
  elif y.isdigit():
    has_digit = True
  elif y.isalnum():
    has_special_char = True
else:
  print("Weak password")


if has_uppercase == True and has_digit == True:
  print("Strong password")
else:
  print("Weak password")
